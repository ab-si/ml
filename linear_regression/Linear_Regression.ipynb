# %% [markdown]
# ### `Linear Regression`
# #### `This jupyter notebook is intended to guide you through basic concepts and working example`
# #### `of Linear Regression. It is perhaps most well known and well understood algorithm in machine learning.`
